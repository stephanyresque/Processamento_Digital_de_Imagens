# %% [markdown]
# <a href="https://colab.research.google.com/github/stephanyresque/Processamento_Digital_de_Imagens/blob/main/Filtros.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
from skimage import io

# %%
#filtro média
img = io.imread("https://boofcv.org/images/thumb/6/66/Kodim17_noisy.jpg/300px-Kodim17_noisy.jpg")

print("Imagem original")
cv2_imshow(img)

print()

m = 3
kernel = np.ones((m,m), np.float32) / (m*m)
filter2D = cv2.filter2D(img, -1, kernel)

print("Imagem filtrada")
cv2_imshow(filter2D)
# Out:
# Imagem original
# <PIL.Image.Image image mode=RGB size=300x300>
# Imagem filtrada
# <PIL.Image.Image image mode=RGB size=300x300>

# %%
#filtro média ponderada

print('imagem original')
cv2_imshow(img)
print()

kernel = np.array([[1,2,1],[2,4,2],[1,2,1]], np.float32) / 16
filter2D = cv2.filter2D(img, -1, kernel)

print('imagem filtrada')
cv2_imshow(filter2D)
# Out:
# imagem original
# <PIL.Image.Image image mode=RGB size=300x300>
# imagem filtrada
# <PIL.Image.Image image mode=RGB size=300x300>

# %%
#filtro mediana

print('imagem original')
cv2_imshow(img)
print()

median = cv2.medianBlur(img, 3)

print('imagem filtrada')
cv2_imshow(median)
# Out:
# imagem original
# <PIL.Image.Image image mode=RGB size=300x300>
# imagem filtrada
# <PIL.Image.Image image mode=RGB size=300x300>

# %%
#filtro Laplaciano
img = io.imread("https://www.melhoresdestinos.com.br/wp-content/uploads/2020/08/novo-castelo-cinderela-disney-capa2019.jpg")
img = cv2.resize(img, (400,400))
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

kernel1 = np.array([[0,1,0],[1,-4,1],[0,1,0]], np.float32)
kernel2 = np.array([[0,-1,0],[-1,4,-1],[0,-1,0]], np.float32)
kernel3 = np.array([[1,1,1],[1,-8,1],[1,1,1]], np.float32)
kernel4 = np.array([[-1,-1,-1],[-1,8,-1],[-1,-1,-1]], np.float32)

# %%
print('imagem original')
cv2_imshow(img)
print()

filter2D1 = cv2.filter2D(img, -1, kernel1)

print('imagem filtrada 1')
cv2_imshow(filter2D1)
print()

filter2D2 = cv2.filter2D(img, -1, kernel2)

print('imagem filtrada 2')
cv2_imshow(filter2D2)
print()

filter2D3 = cv2.filter2D(img, -1, kernel3)

print('imagem filtrada 3')
cv2_imshow(filter2D3)
print()

filter2D4 = cv2.filter2D(img, -1, kernel4)

print('imagem filtrada 4')
cv2_imshow(filter2D4)
# Out:
# imagem original
# <PIL.Image.Image image mode=L size=400x400>
# imagem filtrada 1
# <PIL.Image.Image image mode=L size=400x400>
# imagem filtrada 2
# <PIL.Image.Image image mode=L size=400x400>
# imagem filtrada 3
# <PIL.Image.Image image mode=L size=400x400>
# imagem filtrada 4
# <PIL.Image.Image image mode=L size=400x400>

# %%
#Aguçamento High-Boost

m = 5;
kernel = np.ones((m,m), np.float32) / (m*m)
filter2D = cv2.filter2D(img, -1, kernel)

print('imagem original')
cv2_imshow(img)
print()

print('imagem filtrada')
cv2_imshow(filter2D)

mascara = cv2.subtract(img, filter2D)
agucada = cv2.add(img, 3*mascara)

print()
print('imagem aguçada')
cv2_imshow(agucada)
# Out:
# imagem original
# <PIL.Image.Image image mode=L size=400x400>
# imagem filtrada
# <PIL.Image.Image image mode=L size=400x400>
# imagem aguçada
# <PIL.Image.Image image mode=L size=400x400>

# %%
#Roberts

img = io.imread("https://www.melhoresdestinos.com.br/wp-content/uploads/2020/08/novo-castelo-cinderela-disney-capa2019.jpg")
img = cv2.resize(img, (400,400))
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

roberts1 = np.array([[-1,0],[0,1]])
roberts2 = np.array([[0,-1],[1,0]])

print('imagem original')
cv2_imshow(img)
print()

filter2D1 = cv2.filter2D(img, -1, roberts1)
filter2D2 = cv2.filter2D(img, -1, roberts2)

print('imagem filtrada 1')
cv2_imshow(filter2D1)
print()

print('imagem filtrada 2')
cv2_imshow(filter2D2)
# Out:
# imagem original
# <PIL.Image.Image image mode=L size=400x400>
# imagem filtrada 1
# <PIL.Image.Image image mode=L size=400x400>
# imagem filtrada 2
# <PIL.Image.Image image mode=L size=400x400>
